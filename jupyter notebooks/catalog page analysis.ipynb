# %%
import pandas as pd
import numpy as np
import requests
from bs4 import BeautifulSoup
from google.colab import files
import time

# %%
df = pd.read_csv('catalog page data.csv')

# %%
df.columns
# Out:
# Index(['Text Content', 'Tag', 'Classes', 'xind', 'cat', 'style', 'ID'], dtype='object')

# %%
# this helps detect courses

# %%
temp = df.loc[df['xind'].isin(range(5, 8))]
temp.loc[df['cat'] != 'reqi']
# Out:
#                                           Text Content Tag  \
# 90   Core Courses for Psychology/HCI Concentration ...   p
# 108  Core Courses required for Neuroscience Concent...   p
# 127  Core Courses required for Intelligent Systems ...   p
#
#                                 Classes  xind   cat             style   ID
# 90    ['cat-reqp', 'line-84', 'xind-5']     5  reqp  margin-left:75px  NaN
# 108  ['cat-reqg', 'line-102', 'xind-5']     5  reqg  margin-left:75px  NaN
# 127  ['cat-reqp', 'line-121', 'xind-5']     5  reqp  margin-left:75px  NaN
